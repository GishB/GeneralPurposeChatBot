# %% [markdown]
# ### Task: Загрузить данные в ChromaDB с учетом того что я буду фильтроваться по метаданным
#
#     https://docs.trychroma.com/docs/querying-collections/metadata-filtering
#     https://docs.trychroma.com/docs/querying-collections/full-text-search
#     https://docs.langchain.com/oss/python/integrations/vectorstores/chroma

# %% [markdown]
# # Import libs

# %%
import chromadb

from modules.chroma_ext import ChromaAdapter
from service.context import APP_CTX
# Out:
# /Users/aleksandrsamofalov/PycharmProjects/GeneralPurposeChatBot/src/service/config.py:158: UserWarning: Field name "schema" in "PostgreSettings" shadows an attribute in parent "BaseAppSettings"
#   class PostgreSettings(BaseAppSettings):
# Setting up logging handlers
# Displaying active handlers (1):
#  -- Handler id: 0 | Status: ready | Handler name: standard-loguru
# Successfully removed standard-loguru logger with id 0
# Displaying active handlers (4):
#  -- Handler id: 1 | Status: ready | Handler name: log-file-handler
#  -- Handler id: 2 | Status: ready | Handler name: metric-file-handler
#  -- Handler id: 3 | Status: ready | Handler name: audit-file-handler
#  -- Handler id: 4 | Status: ready | Handler name: log-console-handler
# ---------------- All handlers are ready, now loguru is in charge ----------------
# INFO    | 2026-02-25 00:29:18.425 | service.context | App context initialized.
# INFO    | 2026-02-25 00:29:18.426 | service.context | AppContext
# ...

# %% [markdown]
# # Global args

# %%
await APP_CTX.on_startup()
# Out:
# INFO    | 2026-02-25 00:29:36.246 | service.context | Application is starting up.
# INFO    | 2026-02-25 00:29:36.298 | modules.langfuse_ext.base | LangFuse startup
# INFO    | 2026-02-25 00:29:36.535 | service.context | Langfuse is healthy True
# INFO    | 2026-02-25 00:29:36.536 | modules.chroma_ext.base | Initializing ChromaAdapter
# INFO    | 2026-02-25 00:29:36.537 | modules.chroma_ext.utils.reranker | Initializing BM25Reranker with gpt-3.5-turbo
# INFO    | 2026-02-25 00:29:36.622 | modules.chroma_ext.utils.reranker | BM25Reranker initialized
# INFO    | 2026-02-25 00:29:36.623 | modules.chroma_ext.base | CHROMA_API_KEY: AQVN**h9wc
# INFO    | 2026-02-25 00:29:36.623 | modules.chroma_ext.base | CHROMA_API_URL: https://llm.api.cloud.yandex.net:443/foundationModels/v1/textEmbedding
# INFO    | 2026-02-25 00:29:36.623 | modules.chroma_ext.base | CHROMA_FOLDER_ID: b1g2**508m
# INFO    | 2026-02-25 00:29:36.624 | modules.chroma_ext.base | CHROMA_HOST: 127.0.0.1
# ...

# %%
chroma_client = await APP_CTX.get_chroma()
