# %% [markdown]
# ### Загружаем данные с учетом контроля изменений в документах

# %% [markdown]
# # Import libs

# %%
from service.context import APP_CONFIG, APP_CTX
from modules.chroma_ext.scripts import sync_docx_directory_to_collection, load_docx_with_metadata
# Out:
# /Users/aleksandrsamofalov/PycharmProjects/GeneralPurposeChatBot/src/service/config.py:165: UserWarning: Field name "schema" in "PostgreSettings" shadows an attribute in parent "BaseAppSettings"
#   class PostgreSettings(BaseAppSettings):
# Setting up logging handlers
# Displaying active handlers (1):
#  -- Handler id: 0 | Status: ready | Handler name: standard-loguru
# Successfully removed standard-loguru logger with id 0
# Displaying active handlers (4):
#  -- Handler id: 1 | Status: ready | Handler name: log-file-handler
#  -- Handler id: 2 | Status: ready | Handler name: metric-file-handler
#  -- Handler id: 3 | Status: ready | Handler name: audit-file-handler
#  -- Handler id: 4 | Status: ready | Handler name: log-console-handler
# ---------------- All handlers are ready, now loguru is in charge ----------------
# INFO    | 2026-02-28 23:58:45.875 | service.context | App context initialized.
# INFO    | 2026-02-28 23:58:45.876 | service.context | AppContext
# INFO    | 2026-02-28 23:58:45.876 | service.context | Timezone is Europe/Moscow

# %% [markdown]
# # Define global args

# %%
logger = APP_CTX.logger

# %%
root_dir = "/Users/aleksandrsamofalov/data"

# %% [markdown]
# # Collect data

# %%
import chromadb
client = chromadb.HttpClient(host="127.0.0.1", port=8000)
col = client.get_collection("PROFKOM_NEW")
res = col.get(where={"topic": "Трудовой кодекс"})
print(len(res.get("ids", [])))
# Out:
# 0

# %%
data = load_docx_with_metadata(logger=logger, root_dir=root_dir)

# %%
data[25]
# Out:
# DocumentChunk(id='Трудовой кодекс/Трудовой кодекс Российской Федерации от 30.12.2001 № 197-ФЗ.docx::chunk:25', text='# Титульный текст документа: \n\nДокумент предоставлен КонсультантПлюс 30 декабря 2001 года N 197-ФЗ ТРУДОВОЙ КОДЕКС РОССИЙСКОЙ ФЕДЕРАЦИИ Принят Государственной Думой 21 декабря 2001 года Одобрен Советом Федерации 26 декабря 2001 года Список изменяющих документов (в ред. Федеральных законов от 24.07.2002 N 97-ФЗ, от 25.07.2002 N 116-ФЗ, от 30.06.2003 N 86-ФЗ, от 27.04.2004 N 32-ФЗ, от 22.08.2004 N 122-ФЗ, от 29.12.2004 N 201-ФЗ, от 09.05.2005 N 45-ФЗ, от 30.06.2006 N 90-ФЗ, от 18.12.2006 N 232-ФЗ, от 30.12.2006 N 271-ФЗ, от 20.04.2007 N 54-ФЗ, от 21.07.2007 N 194-ФЗ, от 01.10.2007 N 224-ФЗ, от 18.10.2007 N 230-ФЗ, от 01.12.2007 N 309-ФЗ, от 28.02.2008 N 13-ФЗ, от 22.07.2008 N 157-ФЗ, от 23.07.2008 N 160-ФЗ, от 25.12.2008 N 280-ФЗ, от 25.12.2008 N 281-ФЗ, от 30.12.2008 N 309-ФЗ, от 30.12.2008\n\n## Часть текста по документу: \n\nтом числе в связи с:\n\nнарушением установленных сроков выплаты заработной платы или выплатой ее не в полном размере;\n\nвозникновением непосредственной угрозы для жизни и здоровья работника вследствие нарушения требований охраны труда, в частности необеспечения его средствами коллективной или индивидуальной защиты в соответствии с установленными нормами.\n\n(часть третья в ред. Федерального закона от 30.06.2006 N 90-ФЗ)\n\nДля целей настоящего Кодекса принудительный труд не включает в себя:\n\nработу, выполнение которой обусловлено законодательством о воинской обязанности и военной службе или заменяющей ее альтернативной гражданской службе;\n\nработу, выполнение которой обусловлено введением чрезвычайного или военного положения в порядке, установленно\n\n', metadata={'source': '/Users/aleksandrsamofalov/data/Трудовой кодекс/Трудовой кодекс Российской Федерации от 30.12.2001 № 197-ФЗ.docx', 'rel_path': 'Трудовой кодекс/Трудовой кодекс Российской Федерации от 30.12.2001 № 197-ФЗ.docx', 'topic': 'Трудовой кодекс', 'filename': 'Трудовой кодекс Российской Федерации от 30.12.2001 № 197-ФЗ.docx', 'extension': '.docx', 'chunk_index': 25, 'num_chunks': 1788, 'file_signature': 'b20995766bb58409533d02f46faf0da6', 'topic_prefix_tokens': 120})

# %% [markdown]
# # Load data

# %%
sync_docx_directory_to_collection(logger=logger, root_dir=root_dir, collection_name="PROFKOM_NEW",
**{
    "api_key": APP_CONFIG.chroma.openai_api_key,
    "folder_id": APP_CONFIG.chroma.openai_folder_id,
    "api_url": APP_CONFIG.chroma.embeding_api,
    "host": APP_CONFIG.chroma.host,
    "port": APP_CONFIG.chroma.port
})
# Out:
# INFO    | 2026-02-28 23:58:50.523 | modules.chroma_ext.scripts.db_writer | Chroma: 127.0.0.1:8000, collection=PROFKOM_NEW
# INFO    | 2026-02-28 23:58:50.523 | modules.chroma_ext.scripts.db_writer | Reading .docx from: /Users/aleksandrsamofalov/data
# INFO    | 2026-02-28 23:58:50.524 | modules.chroma_ext.utils.embedings | api_url: https://llm.api.cloud.yandex.net:443/foundationModels/v1/textEmbedding
# INFO    | 2026-02-28 23:58:50.525 | modules.chroma_ext.utils.embedings | iam_token: b1g2***508m
# INFO    | 2026-02-28 23:58:50.525 | modules.chroma_ext.utils.embedings | iam_token: AQVN***h9wc
# INFO    | 2026-02-28 23:58:50.526 | modules.chroma_ext.utils.embedings | time_sleep: 0.05
# INFO    | 2026-02-28 23:58:50.526 | modules.chroma_ext.utils.embedings | text_type: doc
# INFO    | 2026-02-28 23:58:50.526 | modules.chroma_ext.utils.embedings | doc_model_uri: emb://b1g2rs4id5b2cop4508m/text-search-doc/latest
# INFO    | 2026-02-28 23:58:50.527 | modules.chroma_ext.utils.embedings | query_model_uri: emb://b1g2rs4id5b2cop4508m/text-search-query/latest
# INFO    | 2026-02-28 23:58:50.765 | modules.chroma_ext.scripts.db_writer | Loaded 2225 chunks from disk
# INFO    | 2026-02-28 23:58:50.766 | modules.chroma_ext.scripts.db_writer | Processing file: /Users/aleksandrsamofalov/data/Трудовой кодекс/Трудовой кодекс Российской Федерации от 30.12.2001 № 197-ФЗ.docx (signature=b20995766bb58409533d02f46faf0da6)
# INFO    | 2026-02-28 23:58:50.771 | modules.chroma_ext.scripts.db_writer |   -> adding 1788 chunks
# INFO    | 2026-02-28 23:58:50.773 | modules.chroma_ext.utils.embedings | Embedding batch 0, size=16
# INFO    | 2026-02-28 23:58:55.500 | modules.chroma_ext.utils.embedings | Embedding batch 1, size=16
# INFO    | 2026-02-28 23:59:00.166 | modules.chroma_ext.utils.embedings | Embedding batch 2, size=16
# INFO    | 2026-02-28 23:59:05.005 | modules.chroma_ext.utils.embedings | Embedding batch 3, size=16
# INFO    | 2026-02-28 23:59:09.055 | modules.chroma_ext.utils.embedings | Embedding batch 4, size=16
# INFO    | 2026-02-28 23:59:13.101 | modules.chroma_ext.utils.embedings | Embedding batch 5, size=16
